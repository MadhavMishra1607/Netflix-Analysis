# %% [markdown]
# <strong>Analysing a Dataset that contains information about all TV Shows and Movies released by NETFLIX using Python.
# <br>Importing Required Libraries and printing fisrt 5 tuples using head function.</strong>

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
data = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\PYTHON\\Netflix-Analysis-1\\Netflix Analysis\\Netflix Dataset.csv")
data.head()
# Out:
#   Show_Id Category  Title           Director
# 0      s1  TV Show     3%                NaN  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration
# 0    14-Aug-20  TV-MA  4 Seasons  \
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4    01-Jan-20  PG-13    123 min
#
#                                                 Type
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# <strong>Using shape function to get the size of dataset. </strong>

# %%
data.shape
# Out:
# (7789, 11)

# %% [markdown]
# <strong>Using info() function to get indexes, columns, data-types of each column, memory all at once.</strong>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# <strong>Finding and Removing Duplicate Data from our Dataset.</strong>

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director
# 6300    s684    Movie           Backfire     Dave Patten  \
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States  \
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#      Release_Date Rating Duration                                   Type
# 6300    05-Apr-19  TV-MA   97 min  Dramas, Independent Movies, Thrillers  \
# 6622    04-Sep-20  TV-MA   94 min   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# <strong>Finding no. of null values in each colum and Comparing it using Heat map</strong>

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# <strong>Getting Information about a particular Element from our Dataset.
#
# For eg.; Who is the Director of Movie named 1000 Rupee Note and When was it released.</strong>

# %%
data[data['Title'].str.contains("1000 Rupee Note")]
# Out:
#    Show_Id Category            Title        Director
# 59     s60    Movie  1000 Rupee Note  Shrihari Sathe  \
#
#                                                  Cast Country Release_Date
# 59  Usha Naik, Sandeep Pathak, Shrikant Yadav, Gan...   India    01-Dec-16  \
#
#    Rating Duration                          Type
# 59  TV-14   89 min  Dramas, International Movies  \
#
#                                           Description
# 59  After randomly receiving a handsome political ...

# %% [markdown]
# <strong>Checking the No. of Series or Movies that were realesd in a year </strong>

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# <strong>In which year the Highest No. of Movies and TV Shows are released and representing it using a Bar Graph</strong>

# %%
data['New_date'] = pd.to_datetime(data['Release_Date'])
data.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15916\1870908589.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['New_date'] = pd.to_datetime(data['Release_Date'])
#   Show_Id Category  Title           Director
# 0      s1  TV Show     3%                NaN  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration
# 0    14-Aug-20  TV-MA  4 Seasons  \
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4    01-Jan-20  PG-13    123 min
#
#                                                 Type
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description   New_date
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23
# 2  When an army recruit is found dead, his fellow... 2018-12-20
# 3  In a postapocalyptic world, rag-doll robots hi... 2017-11-16
# 4  A brilliant group of students become card-coun... 2020-01-01

# %%
data['New_date'].dt.year.value_counts()
# Out:
# New_date
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data['New_date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='New_date'>

# %% [markdown]
# <strong> Finding all yhe Movies that were Released in the year 2020</strong>

# %%
data['Year'] = data['New_date'].dt.year
data.head()
# Out:
#   Show_Id Category  Title           Director
# 0      s1  TV Show     3%                NaN  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration
# 0    14-Aug-20  TV-MA  4 Seasons  \
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4    01-Jan-20  PG-13    123 min
#
#                                                 Type
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description   New_date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0
# 3  In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017.0
# 4  A brilliant group of students become card-coun... 2020-01-01  2020.0

# %%
data[(data['Category']=='Movie')&(data['Year']==2020)]
# Out:
#      Show_Id Category                                    Title
# 4         s5    Movie                                       21  \
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director
# 4                  Robert Luketic  \
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...                           ...
# 7762                   Wael Ihsan
# 7783                 Peter Hewitt
# 7784                  Josef Fares
# 7786                          NaN
# 7788                     Sam Dunn
#
#                                                    Cast
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  \
# 6     Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
# 14    Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...
# 27                             Yoo Ah-in, Park Shin-hye
# 28                          Helen Mirren, Gengher Gatti
# ...                                                 ...
# 7762  Ahmed Helmy, Yasmin Abdulaziz, Hassan Hosny, H...
# 7783  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7786                                            Nasty C
# 7788                                                NaN
#
#                                                 Country        Release_Date
# 4                                         United States           01-Jan-20  \
# 6                                                 Egypt           06-Jan-20
# 14                                        United States           19-Mar-20
# 27                                          South Korea           08-Sep-20
# 28                                                Italy        July 1, 2020
# ...                                                 ...                 ...
# 7762                                              Egypt           19-May-20
# 7783                                      United States           11-Jan-20
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...           19-Oct-20
# 7786                                                NaN  September 25, 2020
# 7788              United Kingdom, Canada, United States           01-Mar-20
#
#      Rating Duration                                               Type
# 4     PG-13  123 min                                             Dramas  \
# 6     TV-MA   95 min                Horror Movies, International Movies
# 14        R   91 min    Independent Movies, Sci-Fi & Fantasy, Thrillers
# 27    TV-MA   99 min     Horror Movies, International Movies, Thrillers
# 28    TV-14   95 min                Documentaries, International Movies
# ...     ...      ...                                                ...
# 7762  TV-PG  109 min    Comedies, International Movies, Romantic Movies
# 7783     PG   88 min                 Children & Family Movies, Comedies
# 7784  TV-MA   99 min                       Dramas, International Movies
# 7786  TV-MA   44 min  Documentaries, International Movies, Music & M...
# 7788  TV-MA   90 min                    Documentaries, Music & Musicals
#
#                                             Description   New_date    Year
# 4     A brilliant group of students become card-coun... 2020-01-01  2020.0
# 6     After an awful accident, a couple admitted to ... 2020-01-06  2020.0
# 14    Stranded when the Earth is suddenly destroyed ... 2020-03-19  2020.0
# 27    As a grisly virus rampages a city, a lone man ... 2020-09-08  2020.0
# 28    Through her diary, Anne Frank's story is retol... 2020-07-01  2020.0
# ...                                                 ...        ...     ...
# 7762  An unqualified young man has his work cut out ... 2020-05-19  2020.0
# 7783  Dragged from civilian life, a former superhero... 2020-01-11  2020.0
# 7784  When Lebanon's Civil War deprives Zozo of his ... 2020-10-19  2020.0
# 7786  In this documentary, South African rapper Nast... 2020-09-25  2020.0
# 7788  This documentary delves into the mystique behi... 2020-03-01  2020.0
#
# [1312 rows x 13 columns]

# %% [markdown]
# <strong>Finding the Title of all TV Show that are made in India</strong>

# %%
data[ (data['Category']=='TV Show') & (data['Country']=='India') ]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# <strong>Finding Top 10 Directors through the no. of movies and Tv shows they Directed</strong>

# %%
data['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %% [markdown]
# <strong>Applying Conditions:<br>
# "Category is Movie and Type is Comedies" or "Country is United Kingdom"</strong>

# %%
data[(data['Category']=='Movie')&(data['Type']=='Comedies')|(data['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director
# 19       s20    Movie                     '89               NaN  \
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom  \
# 33    Nesta Cooper, Kate Walsh, John Michael Higgins...   United States
# 58    Daniel Palmer, Melissa Sophia, Karen Williams,...  United Kingdom
# 72    Zac Efron, Leslie Mann, Matthew Perry, Thomas ...   United States
# 82    Katee Sackhoff, Ray Fearon, Julie Cox, Steven ...  United Kingdom
# ...                                                 ...             ...
# 7670                                      Robert Powell  United Kingdom
# 7671                 Anita Rani, Ade Adepitan, Dan Snow  United Kingdom
# 7688                                                NaN  United Kingdom
# 7725  Lily O'Regan, Jeannettsy Enriquez Borges, Joel...  United Kingdom
# 7740  Adam Pålsson, Richard Dillane, Leanne Best, El...  United Kingdom
#
#      Release_Date Rating  Duration
# 19      16-May-18  TV-PG    87 min  \
# 33      08-Sep-17  TV-14    99 min
# 58      01-Nov-19  TV-14  1 Season
# 72      01-Jan-21  PG-13   102 min
# 82      20-Dec-18  TV-14    95 min
# ...           ...    ...       ...
# 7670    01-Aug-17  TV-MA  1 Season
# 7671    01-Feb-19  TV-PG  1 Season
# 7688    18-Mar-20  TV-14    91 min
# 7725    31-Dec-17   TV-G    87 min
# 7740    03-Sep-20  TV-MA  1 Season
#
#                                                    Type
# 19                                        Sports Movies  \
# 33                                             Comedies
# 58    British TV Shows, International TV Shows, Real...
# 72                                             Comedies
# 82                                     Sci-Fi & Fantasy
# ...                                                 ...
# 7670  British TV Shows, Docuseries, International TV...
# 7671                       British TV Shows, Docuseries
# 7688                       Documentaries, Sports Movies
# 7725                           Children & Family Movies
# 7740  Crime TV Shows, International TV Shows, TV Dramas
#
#                                             Description   New_date    Year
# 19    Mixing old footage with interviews, this is th... 2018-05-16  2018.0
# 33    When nerdy high schooler Dani finally attracts... 2017-09-08  2017.0
# 58    A stylist, a hair designer and a makeup artist... 2019-11-01  2019.0
# 72    Nearing a midlife crisis, thirty-something Mik... 2021-01-01  2021.0
# 82    Working with an artificial intelligence to inv... 2018-12-20  2018.0
# ...                                                 ...        ...     ...
# 7670  Footage of the most dramatic moments from Worl... 2017-08-01  2017.0
# 7671  From Moscow to Mexico City, three BBC journali... 2019-02-01  2019.0
# 7688  Set against the 2015 Rugby World Cup, this doc... 2020-03-18  2020.0
# 7725  A gifted young ballet dancer struggles to find... 2017-12-31  2017.0
# 7740  An incendiary hate crime stirs civil unrest, f... 2020-09-03  2020.0
#
# [485 rows x 13 columns]

# %% [markdown]
# <strong>Movies/TV Shows in which Tom Cruise was casted?</strong>

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director
# 0      s1  TV Show     3%                NaN  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil    14-Aug-20  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating   Duration                                               Type
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...  \
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
#
#                                          Description   New_date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
#In this Dataset we have few rows in cast cell in empty thus we cannot use str.contains() function.
#Thus we are Creating a new Dataframe in which there is no NULL Value.

data_new = data.dropna()
data_new.head()
# Out:
#   Show_Id Category  Title           Director
# 1      s2    Movie  07:19  Jorge Michel Grau  \
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  \
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#   Release_Date Rating  Duration
# 1    23-Dec-16  TV-MA    93 min  \
# 2    20-Dec-18      R    78 min
# 3    16-Nov-17  PG-13    80 min
# 4    01-Jan-20  PG-13   123 min
# 5    06-Jan-17  TV-MA  1 Season
#
#                                                 Type
# 1                       Dramas, International Movies  \
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
# 5    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description   New_date    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0
# 3  In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017.0
# 4  A brilliant group of students become card-coun... 2020-01-01  2020.0
# 5  A genetics professor experiments with a treatm... 2017-01-06  2017.0

# %%
data_new[data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson  \
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States  \
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#       Release_Date Rating Duration                        Type
# 3860     01-Jan-20      R  189 min  Dramas, Independent Movies  \
# 5071  July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description   New_date    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# <strong>Movies/TV Shows with maximum duration</strong>

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %%
data.head(3)
# Out:
#   Show_Id Category  Title           Director
# 0      s1  TV Show     3%                NaN  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil    14-Aug-20  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating   Duration                                               Type
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...  \
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
#
#                                          Description   New_date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
# Here Datatype is odject, but required dattype is numeric so first we have split the values into two parts-
#One for numerics and Another is for text i.e., min

data[['Minutes','Unit']] = data['Duration'].str.split(' ',expand =True)
data.head()
# Out:
#   Show_Id Category  Title           Director
# 0      s1  TV Show     3%                NaN  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration
# 0    14-Aug-20  TV-MA  4 Seasons  \
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4    01-Jan-20  PG-13    123 min
#
#                                                 Type
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description   New_date    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0  \
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0
# 3  In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017.0
# 4  A brilliant group of students become card-coun... 2020-01-01  2020.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min
# 2      78      min
# 3      80      min
# 4     123      min

# %%
data['Minutes'].max()
# Out:
# '99'

# %% [markdown]
# <strong>Which Country has the Highest No. of TV shows</strong>

# %%
#We have to create a new Dataframe as we require only those Tuples where Category is TV show
data_tvshow = data[data['Category'] == 'TV Show']
data_tvshow.head()
# Out:
#    Show_Id Category   Title              Director
# 0       s1  TV Show      3%                   NaN  \
# 5       s6  TV Show      46           Serdar Akar
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 16     s17  TV Show  Feb-09                   NaN
#
#                                                  Cast                Country
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil  \
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...  Poland, United States
# 12                                                NaN                 Mexico
# 16  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...                    NaN
#
#    Release_Date Rating   Duration
# 0     14-Aug-20  TV-MA  4 Seasons  \
# 5     06-Jan-17  TV-MA   1 Season
# 11    30-Nov-18  TV-MA   1 Season
# 12    17-May-19  TV-MA   1 Season
# 16    20-Mar-19  TV-14   1 Season
#
#                                                  Type
# 0   International TV Shows, TV Dramas, TV Sci-Fi &...  \
# 5     International TV Shows, TV Dramas, TV Mysteries
# 11  Crime TV Shows, International TV Shows, TV Dramas
# 12  Crime TV Shows, Docuseries, International TV S...
# 16                  International TV Shows, TV Dramas
#
#                                           Description   New_date    Year
# 0   In a future where the elite inhabit an island ... 2020-08-14  2020.0  \
# 5   A genetics professor experiments with a treatm... 2017-01-06  2017.0
# 11  In this dark alt-history thriller, a naïve law... 2018-11-30  2018.0
# 12  Archival video and new interviews examine Mexi... 2019-05-17  2019.0
# 16  As a psychology professor faces Alzheimer's, h... 2019-03-20  2019.0
#
#    Minutes     Unit
# 0        4  Seasons
# 5        1   Season
# 11       1   Season
# 12       1   Season
# 16       1   Season

# %%
data_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %% [markdown]
# <strong>Sorting the DataSet Yearwise</strong>

# %%
data.sort_values(by ='Year')
# Out:
#      Show_Id Category                         Title              Director
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu  \
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States  \
# 1765                                                NaN  United States
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
# ...                                                 ...            ...
# 3374                                      Igor Dmitriev            NaN
# 3492  Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...  United States
# 3946  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...  United States
# 5138  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...  United States
# 6066  Luke Jurevicius, Craig Behenna, Charlotte Haml...      Australia
#
#      Release_Date Rating    Duration
# 7115    01-Jan-08  TV-MA      81 min  \
# 1765    04-Feb-08  TV-MA    1 Season
# 3248    05-May-09  TV-MA     104 min
# 5766    18-Nov-09  TV-MA      29 min
# 3840    01-Nov-10     NR      84 min
# ...           ...    ...         ...
# 3374          NaN   TV-Y   2 Seasons
# 3492          NaN  TV-14   3 Seasons
# 3946          NaN  TV-MA   4 Seasons
# 5138          NaN     NR  13 Seasons
# 6066          NaN  TV-Y7   2 Seasons
#
#                                                    Type
# 7115              Dramas, Independent Movies, Thrillers  \
# 1765                       Stand-Up Comedy & Talk Shows
# 3248                       Dramas, International Movies
# 5766                                      Horror Movies
# 3840                         Cult Movies, Horror Movies
# ...                                                 ...
# 3374                                           Kids' TV
# 3492  International TV Shows, Spanish-Language TV Sh...
# 3946                                        TV Comedies
# 5138  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6066                              Kids' TV, TV Comedies
#
#                                             Description   New_date    Year
# 7115  While covering a story in New York City, a Sea... 2008-01-01  2008.0  \
# 1765  In each episode, four celebrities join host Jo... 2008-02-04  2008.0
# 3248  When he causes a car accident that leaves a yo... 2009-05-05  2009.0
# 5766  After committing suicide, a washed-up rocker r... 2009-11-18  2009.0
# 3840  This collection cherry-picks trailers, forgott... 2010-11-01  2010.0
# ...                                                 ...        ...     ...
# 3374  A wacky rabbit and his gang of animal pals hav...        NaT     NaN
# 3492  This irreverent sitcom featues Ludovico, Feder...        NaT     NaN
# 3946  Marc Maron stars as Marc Maron, who interviews...        NaT     NaN
# 5138  This parody of first-person shooter games, mil...        NaT     NaN
# 6066  Imagine your worst fears, then multiply them: ...        NaT     NaN
#
#      Minutes     Unit
# 7115      81      min
# 1765       1   Season
# 3248     104      min
# 5766      29      min
# 3840      84      min
# ...      ...      ...
# 3374       2  Seasons
# 3492       3  Seasons
# 3946       4  Seasons
# 5138      13  Seasons
# 6066       2  Seasons
#
# [7787 rows x 15 columns]

# %%
data.sort_values(by='Year', ascending =False).head()
# Out:
#      Show_Id Category             Title                 Director
# 5564   s5564    Movie   Sherlock Holmes              Guy Ritchie  \
# 5919   s5919    Movie         Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show      Bling Empire                      NaN
# 5955   s5955    Movie  Taare Zameen Par               Aamir Khan
# 366     s367    Movie         Al acecho      Francisco D'Eufemia
#
#                                                    Cast
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...  \
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
# 980                                                 NaN
# 5955  Aamir Khan, Darsheel Safary, Tanay Chheda, Tis...
# 366   Rodrigo de la Serna, Belen Blanco, Walter Jako...
#
#                                                 Country Release_Date Rating
# 5564  United States, Germany, United Kingdom, Australia    01-Jan-21  PG-13  \
# 5919                                      United States    01-Jan-21     PG
# 980                                                 NaN    15-Jan-21  TV-MA
# 5955                                              India    10-Jan-21     PG
# 366                                                 NaN    12-Jan-21  TV-MA
#
#       Duration                                               Type
# 5564   128 min                       Action & Adventure, Comedies  \
# 5919    86 min  Children & Family Movies, Comedies, Sports Movies
# 980   1 Season                                         Reality TV
# 5955   162 min                       Dramas, International Movies
# 366     81 min                    International Movies, Thrillers
#
#                                             Description   New_date    Year
# 5564  The game is afoot for an eccentric detective w... 2021-01-01  2021.0  \
# 5919  This Oscar-nominated animated comedy goes behi... 2021-01-01  2021.0
# 980   Follow LA's wildly wealthy Asian and Asian Ame... 2021-01-15  2021.0
# 5955  When daydreamer Ishaan is sent to boarding sch... 2021-01-10  2021.0
# 366   Looking for a fresh start, a park ranger gets ... 2021-01-12  2021.0
#
#      Minutes    Unit
# 5564     128     min
# 5919      86     min
# 980        1  Season
# 5955     162     min
# 366       81     min

# %% [markdown]
# <strong>Gathering all rows where:<br>
# Category is 'Movie' and Type is 'Dramas'
# <I> OR </I>
# Category is 'TV Show' and Type is 'Kids TV'
# </strong>

# %%
#First Condition
data[(data['Category']=='Movie') & (data['Type']=='Dramas')].head()
# Out:
#     Show_Id Category                       Title        Director
# 4        s5    Movie                          21  Robert Luketic  \
# 7        s8    Movie                         187  Kevin Reynolds
# 170    s171    Movie                A Family Man   Mark Williams
# 232    s233    Movie  A Stoning in Fulham County   Larry Elikann
# 295    s296    Movie          Across Grace Alley   Ralph Macchio
#
#                                                   Cast                Country
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          United States  \
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...          United States
# 170  Gerard Butler, Gretchen Mol, Alison Brie, Will...  Canada, United States
# 232  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...          United States
# 295  Ben Hyland, Marsha Mason, Karina Smirnoff, Col...          United States
#
#     Release_Date Rating Duration    Type
# 4      01-Jan-20  PG-13  123 min  Dramas  \
# 7      01-Nov-19      R  119 min  Dramas
# 170    15-Dec-19      R  110 min  Dramas
# 232    01-Oct-11  TV-14   95 min  Dramas
# 295    01-Dec-16  TV-PG   24 min  Dramas
#
#                                            Description   New_date    Year
# 4    A brilliant group of students become card-coun... 2020-01-01  2020.0  \
# 7    After one of his high school students attacks ... 2019-11-01  2019.0
# 170  A ruthless corporate headhunter battles his ri... 2019-12-15  2019.0
# 232  After reckless teens kill an Amish child, a pr... 2011-10-01  2011.0
# 295  A young boy, upset by his parents' divorce, be... 2016-12-01  2016.0
#
#     Minutes Unit
# 4       123  min
# 7       119  min
# 170     110  min
# 232      95  min
# 295      24  min

# %%
# Second Condition
data[(data['Category']=='TV Show') & (data['Type']=="Kids' TV")].head()
# Out:
#     Show_Id Category              Title             Director
# 111    s112  TV Show            44 Cats                  NaN  \
# 276    s277  TV Show       Abby Hatcher          Kyran Kelly
# 434    s435  TV Show        Alphablocks                  NaN
# 598    s599  TV Show  Ask the StoryBots                  NaN
# 706    s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
#
#                                                   Cast                Country
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy  \
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
# 434    Teresa Gallagher, David Holt, Lizzie Waterworth         United Kingdom
# 598  Judy Greer, Erin Fitzgerald, Fred Tatasciore, ...          United States
# 706             Meghna Erande Joshi, Parminder Ghumman                    NaN
#
#      Release_Date Rating   Duration      Type
# 111     01-Oct-20  TV-Y7  2 Seasons  Kids' TV  \
# 276  July 1, 2020   TV-Y   1 Season  Kids' TV
# 434     25-May-20   TV-Y  5 Seasons  Kids' TV
# 598     02-Aug-19   TV-Y  3 Seasons  Kids' TV
# 706     31-Mar-20  TV-Y7   1 Season  Kids' TV
#
#                                            Description   New_date    Year
# 111  Paw-esome tales abound when singing furry frie... 2020-10-01  2020.0  \
# 276  A big-hearted girl helps her Fuzzly friends wh... 2020-07-01  2020.0
# 434  The letters of the alphabet come to life in Al... 2020-05-25  2020.0
# 598  Five curious little creatures track down the a... 2019-08-02  2019.0
# 706  Watch Ganesh destroy demons, disarm invaders a... 2020-03-31  2020.0
#
#     Minutes     Unit
# 111       2  Seasons
# 276       1   Season
# 434       5  Seasons
# 598       3  Seasons
# 706       1   Season

# %%
# Combining Above Two:
data[(data['Category']=='Movie') & (data['Type']=='Dramas') | (data['Category']=='TV Show') & (data['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director
# 4         s5    Movie                          21  Robert Luketic  \
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  \
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 170   Gerard Butler, Gretchen Mol, Alison Brie, Will...
# 232   Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...
# ...                                                 ...
# 7668  Haven Paschall, Alysha Deslorieux, Jessica Paq...
# 7717  Eileen Stevens, Alyson Leigh Rosenfeld, Sarah ...
# 7719  Sairaj, Devyani Dagaonkar, Ketan Singh, Mayur ...
# 7758  Apollo Costa, Gabriel Santana, Matheus Lustosa...
# 7761  Michael Johnston, Jessica Gee-George, Christin...
#
#                                             Country        Release_Date
# 4                                     United States           01-Jan-20  \
# 7                                     United States           01-Nov-19
# 111                                           Italy           01-Oct-20
# 170                           Canada, United States           15-Dec-19
# 232                                   United States           01-Oct-11
# ...                                             ...                 ...
# 7668                           Italy, United States       June 16, 2017
# 7717                                            NaN       June 23, 2018
# 7719                                            NaN        June 7, 2018
# 7758                                         Brazil           22-Feb-19
# 7761  United States, France, South Korea, Indonesia  September 13, 2018
#
#      Rating   Duration      Type
# 4     PG-13    123 min    Dramas  \
# 7         R    119 min    Dramas
# 111   TV-Y7  2 Seasons  Kids' TV
# 170       R    110 min    Dramas
# 232   TV-14     95 min    Dramas
# ...     ...        ...       ...
# 7668  TV-Y7  2 Seasons  Kids' TV
# 7717   TV-Y   1 Season  Kids' TV
# 7719  TV-Y7   1 Season  Kids' TV
# 7758  TV-PG  2 Seasons  Kids' TV
# 7761  TV-Y7  3 Seasons  Kids' TV
#
#                                             Description   New_date    Year
# 4     A brilliant group of students become card-coun... 2020-01-01  2020.0  \
# 7     After one of his high school students attacks ... 2019-11-01  2019.0
# 111   Paw-esome tales abound when singing furry frie... 2020-10-01  2020.0
# 170   A ruthless corporate headhunter battles his ri... 2019-12-15  2019.0
# 232   After reckless teens kill an Amish child, a pr... 2011-10-01  2011.0
# ...                                                 ...        ...     ...
# 7668  The reality show "WOW!" engages the Winx in th... 2017-06-16  2017.0
# 7717  Friends Mai, Oto and Vik's games at the park b... 2018-06-23  2018.0
# 7719  With the mind of a human being, and the body o... 2018-06-07  2018.0
# 7758  Fading music biz veteran Zé realizes he has ju... 2019-02-22  2019.0
# 7761  Teen surfer Zak Storm is mysteriously transpor... 2018-09-13  2018.0
#
#      Minutes     Unit
# 4        123      min
# 7        119      min
# 111        2  Seasons
# 170      110      min
# 232       95      min
# ...      ...      ...
# 7668       2  Seasons
# 7717       1   Season
# 7719       1   Season
# 7758       2  Seasons
# 7761       3  Seasons
#
# [322 rows x 15 columns]
